# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
combined = pd.read_csv("https://raw.githubusercontent.com/nicolepng/BT4222/main/Data/combined.csv")

# %%
combined = combined.drop(combined.columns[0], axis=1)

# %%
combined.head()
# Out:
#    district             street   propertyType  remaining_lease      price  \
# 0         5       ZEHNDER ROAD  Semi-detached           999.00  5500000.0
# 1         5       ZEHNDER ROAD  Semi-detached           999.00  5000000.0
# 2         5       ZEHNDER ROAD  Semi-detached           999.00  4750000.0
# 3         5  NEO PEE TECK LANE        Terrace           999.00  2630000.0
# 4         4         COVE DRIVE    Condominium            85.25  3180000.0
#
#    school  hawkercentre  supermarkets  Bus Stops Nearby  crime_number  \
# 0      27             6             8                 0          -1.0
# 1      27             6             8                 0          -1.0
# 2      27             6             8                 0          -1.0
# 3      27             6             8                 2          -1.0
# 4      11             3             2                 0          -1.0
#
#    latitude   longitude  floor_area_sqm floor_range  sentiment
# 0  1.282130  103.786879           524.3           -   0.154684
# 1  1.282130  103.786879           308.0           -   0.122456
# 2  1.282130  103.786879           314.0           -   0.122456
# 3  1.292047  103.768591           159.3           -   0.154684
# 4  1.244208  103.827487           194.0       01-05   0.128195

# %% [markdown]
# ## Descriptive Analysis

# %%
combined.describe()
# Out:
#             district  remaining_lease         price         school  \
# count  133690.000000    133690.000000  1.336900e+05  133690.000000
# mean       18.176647       243.957049  9.659421e+05      32.917660
# std         5.357858      5479.242737  1.630981e+06       9.410736
# min         1.000000         2.580000  4.000000e+04      10.000000
# 25%        16.000000        67.170000  3.700000e+05      25.000000
# 50%        20.000000        80.330000  5.050000e+05      37.000000
# 75%        20.000000        93.420000  9.500000e+05      37.000000
# max        28.000000    999973.000000  1.090000e+08      51.000000
#
#         hawkercentre   supermarkets  Bus Stops Nearby   crime_number  \
# count  133690.000000  133690.000000     133690.000000  133690.000000
# mean        7.020226      10.229396          0.116344     123.908333
# std         4.201369       5.571115          0.352231      58.367808
# min         1.000000       1.000000          0.000000      -1.000000
# 25%         4.000000       5.000000          0.000000      78.928571
# 50%         5.000000      11.000000          0.000000     122.714286
# 75%        11.000000      14.000000          0.000000     167.714286
# max        16.000000      39.000000          2.000000     226.000000
#
#             latitude      longitude  floor_area_sqm      sentiment
# count  133690.000000  133690.000000   133690.000000  133690.000000
# mean        1.358712     103.845242      114.587490       0.118738
# std         0.043492       0.068366       88.967348       0.034276
# min         1.239641     103.687191       24.000000      -0.039881
# 25%         1.325827     103.794725       84.000000       0.096782
# 50%         1.355269     103.847709      102.000000       0.126775
# 75%         1.389063     103.898665      121.000000       0.135898
# max         1.460839     103.987293     4836.400000       0.317045

# %%
combined.dtypes
# Out:
# district              int64
# street               object
# propertyType         object
# remaining_lease     float64
# price               float64
# school                int64
# hawkercentre          int64
# supermarkets          int64
# Bus Stops Nearby      int64
# crime_number        float64
# latitude            float64
# longitude           float64
# floor_area_sqm      float64
# floor_range          object
# sentiment           float64
# dtype: object

# %%
combined['district'] = combined['district'].astype(str)

# %% [markdown]
# ## Correlation Analysis
# > Including Correlation Values

# %%
# correlation analysis
corr = combined.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1.0, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot = True)

# %% [markdown]
# ## Examining Number of Records in Each Category Pre Normalisation

# %% [markdown]
# > Bar Plots

# %%
combined['district'].value_counts().plot(kind='bar')

# %%
combined['propertyType'].value_counts().plot(kind='bar')

# %%
combined['floor_range'].value_counts().plot(kind='bar')

# %% [markdown]
# ## Variation of Variables with Price

# %% [markdown]
# > Pairplot

# %%
def pairplot(x, y, **kwargs):
    ax = plt.gca()
    ts = pd.DataFrame({'time': x, 'val': y})
    ts = ts.groupby('time').mean()
    ts.plot(ax=ax)
    plt.xticks(rotation=90)
    
vals = ['district',            
'street',              
'propertyType',      
'remaining_lease',     
'school',             
'hawkercentre',        
'supermarkets',        
'Bus Stops Nearby',   
'crime_number',        
'latitude',           
'longitude',           
'floor_area_sqm',     
'floor_range',         
'sentiment']   
f = pd.melt(combined, id_vars=['price'], value_vars=vals)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False, size=5)
g = g.map(pairplot, "value", "price")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# > Scatterplot

# %%
for i in range(len(vals)):
    plt.scatter(combined[vals[i]],combined["price"])
    plt.ylabel("Price")
    plt.xlabel(vals[i]);
    plt.xticks(rotation=90)
    plt.show()

# %%
combined.columns
# Out:
# Index(['district', 'street', 'propertyType', 'remaining_lease', 'price',
#        'school', 'hawkercentre', 'supermarkets', 'Bus Stops Nearby',
#        'crime_number', 'latitude', 'longitude', 'floor_area_sqm',
#        'floor_range', 'sentiment'],
#       dtype='object')

# %% [markdown]
# ## Examining Categorical Variables against Price

# %% [markdown]
# > District

# %%
sns.barplot(combined["district"],combined["price"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# > Property Type

# %%
sns.barplot(combined["propertyType"],combined["price"])
plt.xticks(rotation=90)
plt.tight_layout()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# > Schools Nearby

# %%
sns.barplot(combined["school"],combined["price"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# > Hawker Centres Nearby

# %%
sns.barplot(combined["hawkercentre"],combined["price"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.barplot(combined["floor_range"],combined["price"])
plt.xticks(rotation=90)
plt.tight_layout()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.barplot(combined["supermarkets"],combined["price"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Examine Number of Crimes within Districts

# %%
sns.barplot(combined["district"],combined["crime_number"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Examining the Types of Properties amongst Districts

# %%
sns.countplot(combined["district"],hue = combined["propertyType"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Overall Sentiment Per District

# %%
sns.barplot(combined["district"],combined["sentiment"])

# %% [markdown]
# ## Supermarkets in each district

# %% [markdown]
# > Number of Supermarkets in all districts the same? might need to check data cleaning

# %%
sns.barplot(combined["district"],combined["supermarkets"])

# %% [markdown]
# ## Hawkercentres Per District

# %%
sns.barplot(combined["district"],combined["hawkercentre"])

# %% [markdown]
# ## Schools Per District

# %%
sns.barplot(combined["district"],combined["school"])

# %% [markdown]
# ## Floor Area Per District

# %%
sns.barplot(combined["district"], combined["floor_area_sqm"])

# %% [markdown]
# ## Remaining Lease Per District

# %%
sns.barplot(combined["district"], combined["remaining_lease"])
