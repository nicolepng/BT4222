# %%
#from google.colab import drive
#drive.mount('/content/drive')

#!ls "/content/drive/My Drive/BT4222 Data/combined.csv"
#path = '/content/drive/My Drive/BT4222 Data/combined.csv'
#combined = pd.read_csv(path)
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
combined = pd.read_csv("/Users/admin/Desktop/Y3S2/BT4222/combined.csv")

# %% [markdown]
# ## Descriptive Analysis

# %%
combined.describe()
# Out:
#             district         street   propertyType  remaining_lease  \
# count  132607.000000  132607.000000  132607.000000    132607.000000
# mean       18.193391    1018.356746       4.557957       241.866623
# std         5.345945     658.598106       2.767148      5501.373380
# min         1.000000       0.000000       0.000000         2.580000
# 25%        16.000000     355.000000       3.000000        67.080000
# 50%        20.000000    1063.000000       4.000000        80.250000
# 75%        20.000000    1581.000000       6.000000        93.330000
# max        28.000000    2004.000000      15.000000    999973.000000
#
#               price         school   hawkercentre   supermarkets  \
# count  1.326070e+05  132607.000000  132607.000000  132607.000000
# mean   9.562546e+05      32.928767       7.036763      10.218465
# std    1.622821e+06       9.401591       4.202423       5.566862
# min    4.000000e+04      10.000000       1.000000       1.000000
# 25%    3.700000e+05      25.000000       4.000000       5.000000
# 50%    5.000000e+05      37.000000       5.000000      11.000000
# 75%    9.350000e+05      37.000000      11.000000      14.000000
# max    1.090000e+08      51.000000      16.000000      39.000000
#
#        Bus Stops Nearby   crime_number       latitude      longitude  \
# count     132607.000000  132607.000000  132607.000000  132607.000000
# mean           0.121479     124.066175       1.358879     103.845187
# std            0.362613      58.140970       0.043521       0.068382
# min            0.000000      -1.000000       1.239641     103.687191
# 25%            0.000000      78.928571       1.326058     103.793446
# 50%            0.000000     122.714286       1.355269     103.847709
# 75%            0.000000     167.714286       1.389063     103.898665
# max            2.000000     226.000000       1.460839     103.987293
#
#        floor_area_sqm    floor_range      sentiment
# count   132607.000000  132607.000000  132607.000000
# mean       114.282205       2.038180       0.072803
# std         88.556745       1.391485       0.018810
# min         24.000000       0.000000      -0.025054
# 25%         84.000000       1.000000       0.056981
# 50%        102.000000       2.000000       0.069542
# 75%        121.000000       3.000000       0.083862
# max       4836.400000      17.000000       0.229515

# %% [markdown]
# ## Correlation Analysis
# > Including Correlation Values

# %%
# correlation analysis
corr = combined.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1.0, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot = True)

# %% [markdown]
# ## Examining Number of Records in Each Category Pre Normalisation

# %% [markdown]
# > Bar Plots

# %%
combined['district'].value_counts().plot(kind='bar')

# %%
combined['propertyType'].value_counts().plot(kind='bar')

# %%
combined['floor_range'].value_counts().plot(kind='bar')

# %% [markdown]
# ## Variation of Variables with Price

# %% [markdown]
# > Pairplot

# %%
def pairplot(x, y, **kwargs):
    ax = plt.gca()
    ts = pd.DataFrame({'time': x, 'val': y})
    ts = ts.groupby('time').mean()
    ts.plot(ax=ax)
    plt.xticks(rotation=90)
    
vals = ['district',            
'street',              
'propertyType',      
'remaining_lease',     
'school',             
'hawkercentre',        
'supermarkets',        
'Bus Stops Nearby',   
'crime_number',        
'latitude',           
'longitude',           
'floor_area_sqm',     
'floor_range',         
'sentiment']   
f = pd.melt(combined, id_vars=['price'], value_vars=vals)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False, size=5)
g = g.map(pairplot, "value", "price")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# > Scatterplot

# %%
for i in range(len(vals)):
  plt.scatter(combined[vals[i]],combined["price"])
  plt.ylabel("Price")
  plt.xlabel(vals[i]);
  plt.show()

# %% [markdown]
# ## Examining Categorical Variables against Price

# %% [markdown]
# > District

# %%
sns.barplot(combined["district"],combined["price"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# > Property Type

# %%
sns.barplot(combined["propertyType"],combined["price"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# > Schools Nearby

# %%
sns.barplot(combined["school"],combined["price"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# > Hawker Centres Nearby

# %%
sns.barplot(combined["hawkercentre"],combined["price"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Examine Number of Crimes within Districts

# %%
sns.barplot(combined["district"],combined["crime_number"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Examining the Types of Properties amongst Districts

# %%
sns.barplot(combined["district"],combined["propertyType"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Overall Sentiment Per District

# %%
sns.barplot(combined["district"],combined["sentiment"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Supermarkets in each district

# %% [markdown]
# > Number of Supermarkets in all districts the same? might need to check data cleaning

# %%
sns.barplot(combined["district"],combined["supermarkets"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Hawkercentres Per District

# %%
sns.barplot(combined["district"],combined["hawkercentre"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Schools Per District

# %%
sns.barplot(combined["district"],combined["school"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
