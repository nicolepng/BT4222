# %%
# Import packages
import matplotlib.pyplot as plt 
import pandas as pd

# %% [markdown]
# ## Load Datasets

# %% [markdown]
# (1) URA Dataset

# %%
ura_url = 'https://raw.githubusercontent.com/nicolepng/BT4222/main/Data/ura_5y_trans.csv'
ura_5y_trans = pd.read_csv(ura_url)
ura_5y_trans.drop(ura_5y_trans.columns[0], axis=1, inplace=True)
print(ura_5y_trans.shape)
ura_5y_trans.head()
# Out:
# (73174, 19)
#               street                     project marketSegment   area  \
# 0       ZEHNDER ROAD  LANDED HOUSING DEVELOPMENT           RCR  524.3
# 1       ZEHNDER ROAD  LANDED HOUSING DEVELOPMENT           RCR  308.0
# 2       ZEHNDER ROAD  LANDED HOUSING DEVELOPMENT           RCR  314.0
# 3  NEO PEE TECK LANE  LANDED HOUSING DEVELOPMENT           RCR  159.3
# 4         COVE DRIVE                   TURQUOISE           CCR  226.0
#
#   floorRange  noOfUnits  contractDate  typeOfSale    price   propertyType  \
# 0          -          1           220           3  5500000  Semi-detached
# 1          -          1           918           3  5000000  Semi-detached
# 2          -          1           618           3  4750000  Semi-detached
# 3          -          1           320           3  2630000        Terrace
# 4      01-05          1           920           3  3400000    Condominium
#
#    district typeOfArea                             tenure            x  \
# 0         5       Land                           Freehold          NaN
# 1         5       Land                           Freehold          NaN
# 2         5       Land                           Freehold          NaN
# 3         5       Land                           Freehold          NaN
# 4         4     Strata  99 yrs lease commencing from 2007  28382.47067
#
#              y  nettPrice  latitude   longitude  year
# 0          NaN        NaN  1.282130  103.786879    20
# 1          NaN        NaN  1.282130  103.786879    18
# 2          NaN        NaN  1.282130  103.786879    18
# 3          NaN        NaN  1.292047  103.768591    20
# 4  25008.33592        NaN  1.244208  103.827487    20

# %% [markdown]
# (2) Ameneties Dataset

# %%
amenities_url = 'https://raw.githubusercontent.com/nicolepng/BT4222/main/Data/ameneties_per_district.csv' 
ameneties_per_district = pd.read_csv(amenities_url)
ameneties_per_district.drop(ameneties_per_district.columns[0], axis=1, inplace=True)
print(ameneties_per_district.shape)
ameneties_per_district.head()
# Out:
# (28, 4)
#    district                                             school  \
# 0         1  ['NORTHLIGHT SCHOOL', 'DAMAI SECONDARY SCHOOL'...
# 1         2  ['QUEENSTOWN SECONDARY SCHOOL', 'GAN ENG SENG ...
# 2         3  ['SCHOOL OF SCIENCE AND TECHNOLOGY, SINGAPORE'...
# 3         4  ['QUEENSTOWN SECONDARY SCHOOL', "ST. MARGARET'...
# 4         5  ['JURONG SECONDARY SCHOOL', 'SCHOOL OF SCIENCE...
#
#                                         hawkercentre  \
# 0                                                 []
# 1                                                 []
# 2  ['Bukit Merah Lane 1 Blk 120 (Alexandra Villag...
# 3  ['Telok Blangah Drive Blk 79 (Telok Blangah Fo...
# 4  ['West Coast Drive Blk 503 (Ayer Rajah Food Ce...
#
#                                         supermarkets
# 0                                                 []
# 1                                                 []
# 2  ['YOUR GROCER PRIVATE LIMITED', 'COLD STORAGE ...
# 3  ['NTUC FAIRPRICE CO-OPERATIVE LTD', 'THE QUALI...
# 4  ['U STARS SUPERMARKET PTE. LTD.', 'NTUC FAIRPR...

# %% [markdown]
# (3) Bus Stops Dataset

# %%
# Obtain bus stop data
bus_stops_url = 'https://raw.githubusercontent.com/nicolepng/BT4222/main/Data/bus_stops.csv' 
bus_stops = pd.read_csv(bus_stops_url)
bus_stops.drop(bus_stops.columns[0], axis=1, inplace=True)
print(bus_stops.shape)
bus_stops.head()
# Out:
# (5021, 5)
#    BusStopCode       RoadName             Description  Latitude   Longitude
# 0          481   Woodlands Rd  BT PANJANG TEMP BUS PK  1.383764  103.758300
# 1         1012    Victoria St     Hotel Grand Pacific  1.296848  103.852536
# 2         1013    Victoria St         St. Joseph's Ch  1.297710  103.853225
# 3         1019    Victoria St         Bras Basah Cplx  1.296990  103.853022
# 4         1029  Nth Bridge Rd   Cosmic Insurance Bldg  1.296673  103.854414

# %% [markdown]
# (4.1) Crime Locations Dataset - Overview

# %%
crime_locations_url = 'https://raw.githubusercontent.com/nicolepng/BT4222/main/Data/overview_years_crimes_locations_v3.csv' 
overview_years_crimes_locations_v3 = pd.read_csv(crime_locations_url)
overview_years_crimes_locations_v3.drop(overview_years_crimes_locations_v3.columns[3], axis=1, inplace=True) # dropped 'Number (Cases)' column coz only difference between this and 'Number' is that 'Number' states the 0s
print(overview_years_crimes_locations_v3.shape)
overview_years_crimes_locations_v3.head()
# Out:
# (1680, 6)
#    Year                              NPC                 Offence  \
# 0  2012  Central Police Division - Total                 Robbery
# 1  2012  Central Police Division - Total           Housebreaking
# 2  2012  Central Police Division - Total            Snatch Theft
# 3  2012  Central Police Division - Total  Theft Of Motor Vehicle
# 4  2012  Central Police Division - Total      Outrage Of Modesty
#
#                             Neighbourhood Postal  Number
# 0  [Total]Central Police Division - Total      -      34
# 1  [Total]Central Police Division - Total      -      32
# 2  [Total]Central Police Division - Total      -      31
# 3  [Total]Central Police Division - Total      -      47
# 4  [Total]Central Police Division - Total      -     193

# %% [markdown]
# (4.2) Crime Locations Dataset - Average

# %%
avg_crime_locations_url = 'https://raw.githubusercontent.com/nicolepng/BT4222/main/Data/average_crimes_by_location_v3.csv' 
average_crimes_by_location_v3 = pd.read_csv(avg_crime_locations_url)
average_crimes_by_location_v3
# Out:
#                                 Neighbourhood  Postal                 Offence  \
# 0                           Ang Mo Kio North   569784           Housebreaking
# 1                           Ang Mo Kio North   569784      Outrage Of Modesty
# 2                           Ang Mo Kio North   569784                 Robbery
# 3                           Ang Mo Kio North   569784            Snatch Theft
# 4                           Ang Mo Kio North   569784  Theft Of Motor Vehicle
# ..                                        ...     ...                     ...
# 210  [Total]Woodlands Police Division - Total       -           Housebreaking
# 211  [Total]Woodlands Police Division - Total       -      Outrage Of Modesty
# 212  [Total]Woodlands Police Division - Total       -                 Robbery
# 213  [Total]Woodlands Police Division - Total       -            Snatch Theft
# 214  [Total]Woodlands Police Division - Total       -  Theft Of Motor Vehicle
#
#         Number
# 0     4.857143
# 1    26.000000
# 2     2.000000
# 3     2.714286
# 4     5.000000
# ..         ...
# 210   0.285714
# 211   2.142857
# 212   0.000000
# 213   0.000000
# 214   0.142857
#
# [215 rows x 4 columns]

# %% [markdown]
# (5) Resale Flat Prices Dataset

# %%
resale_flat_prices_url = 'https://raw.githubusercontent.com/nicolepng/BT4222/main/Data/resale_flat_prices_based_on_registration_date_from_jan_2017_onwards.csv'
resale_flat_prices = pd.read_csv(resale_flat_prices_url)
resale_flat_prices.drop(resale_flat_prices.columns[0], axis=1, inplace=True)
print(resale_flat_prices.shape)
resale_flat_prices.head()
# Out:
# (92235, 14)
#      month        town flat_type block        street_name storey_range  \
# 0  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3  2017-01  ANG MO KIO    3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4  2017-01  ANG MO KIO    3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date     remaining_lease  \
# 0            44.0        Improved                 1979  61 years 04 months
# 1            67.0  New Generation                 1978  60 years 07 months
# 2            67.0  New Generation                 1980  62 years 05 months
# 3            68.0  New Generation                 1980   62 years 01 month
# 4            67.0  New Generation                 1980  62 years 05 months
#
#    resale_price             street  latitude   longitude
# 0      232000.0  ANG MO KIO AVE 10  1.367602  103.856844
# 1      250000.0   ANG MO KIO AVE 4  1.382319  103.838706
# 2      262000.0   ANG MO KIO AVE 5  1.376825  103.847556
# 3      265000.0  ANG MO KIO AVE 10  1.367602  103.856844
# 4      265000.0   ANG MO KIO AVE 5  1.376825  103.847556

# %% [markdown]
# ## Combination of Datasets
# 1. ameneties_in_district = ura_5y_trans + ameneties_per_district
# 2. ameneties_in_district = ameneties_in_district + bus_stops
# 3. ameneties_and_crimes_in_district = ameneties_in_district + average_crimes_by_location_v3

# %% [markdown]
# ## 1. Combine URA and ameneties

# %%
# combine ura_5y_trans and ameneties_per_district
ameneties_in_district = ura_5y_trans.join(ameneties_per_district.set_index('district'), on='district')
print(ameneties_in_district.shape)
ameneties_in_district.head()
# Out:
# (73174, 22)
#               street                     project marketSegment   area  \
# 0       ZEHNDER ROAD  LANDED HOUSING DEVELOPMENT           RCR  524.3
# 1       ZEHNDER ROAD  LANDED HOUSING DEVELOPMENT           RCR  308.0
# 2       ZEHNDER ROAD  LANDED HOUSING DEVELOPMENT           RCR  314.0
# 3  NEO PEE TECK LANE  LANDED HOUSING DEVELOPMENT           RCR  159.3
# 4         COVE DRIVE                   TURQUOISE           CCR  226.0
#
#   floorRange  noOfUnits  contractDate  typeOfSale    price   propertyType  \
# 0          -          1           220           3  5500000  Semi-detached
# 1          -          1           918           3  5000000  Semi-detached
# 2          -          1           618           3  4750000  Semi-detached
# 3          -          1           320           3  2630000        Terrace
# 4      01-05          1           920           3  3400000    Condominium
#
#    ...                             tenure            x            y  \
# 0  ...                           Freehold          NaN          NaN
# 1  ...                           Freehold          NaN          NaN
# 2  ...                           Freehold          NaN          NaN
# 3  ...                           Freehold          NaN          NaN
# 4  ...  99 yrs lease commencing from 2007  28382.47067  25008.33592
#
#    nettPrice  latitude   longitude  year  \
# 0        NaN  1.282130  103.786879    20
# 1        NaN  1.282130  103.786879    18
# 2        NaN  1.282130  103.786879    18
# 3        NaN  1.292047  103.768591    20
# 4        NaN  1.244208  103.827487    20
#
#                                               school  \
# 0  ['JURONG SECONDARY SCHOOL', 'SCHOOL OF SCIENCE...
# 1  ['JURONG SECONDARY SCHOOL', 'SCHOOL OF SCIENCE...
# 2  ['JURONG SECONDARY SCHOOL', 'SCHOOL OF SCIENCE...
# 3  ['JURONG SECONDARY SCHOOL', 'SCHOOL OF SCIENCE...
# 4  ['QUEENSTOWN SECONDARY SCHOOL', "ST. MARGARET'...
#
#                                         hawkercentre  \
# 0  ['West Coast Drive Blk 503 (Ayer Rajah Food Ce...
# 1  ['West Coast Drive Blk 503 (Ayer Rajah Food Ce...
# 2  ['West Coast Drive Blk 503 (Ayer Rajah Food Ce...
# 3  ['West Coast Drive Blk 503 (Ayer Rajah Food Ce...
# 4  ['Telok Blangah Drive Blk 79 (Telok Blangah Fo...
#
#                                         supermarkets
# 0  ['U STARS SUPERMARKET PTE. LTD.', 'NTUC FAIRPR...
# 1  ['U STARS SUPERMARKET PTE. LTD.', 'NTUC FAIRPR...
# 2  ['U STARS SUPERMARKET PTE. LTD.', 'NTUC FAIRPR...
# 3  ['U STARS SUPERMARKET PTE. LTD.', 'NTUC FAIRPR...
# 4  ['NTUC FAIRPRICE CO-OPERATIVE LTD', 'THE QUALI...
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 2. Combine Combined URA (ameneties_in_district) and Bus Stops

# %% [markdown]
# Calculate number of bus stops near each listing

# %%
# Formula to calculate distance 
from math import cos, sqrt
R = 6371000 #radius of the Earth in m
def distance(lon1, lat1, lon2, lat2):
    x = (lon2 - lon1) * cos(0.5*(lat2+lat1))
    y = (lat2 - lat1)
    return R * sqrt( x*x + y*y )

# %%
busStops = bus_stops.to_dict(orient='records')

# %%
# threshold of within 1km
numOfStops = []
for long, lat in zip(ameneties_in_district.longitude, ameneties_in_district.latitude):
    buslist = list(filter(lambda d: distance(d["Longitude"], d["Latitude"], long, lat) <= 1000, busStops))
    numOfStops.append(len(buslist))

# %%
ameneties_in_district['Bus Stops Nearby'] = numOfStops

# %%
ameneties_in_district.head()
# Out:
#               street                     project marketSegment   area  \
# 0       ZEHNDER ROAD  LANDED HOUSING DEVELOPMENT           RCR  524.3
# 1       ZEHNDER ROAD  LANDED HOUSING DEVELOPMENT           RCR  308.0
# 2       ZEHNDER ROAD  LANDED HOUSING DEVELOPMENT           RCR  314.0
# 3  NEO PEE TECK LANE  LANDED HOUSING DEVELOPMENT           RCR  159.3
# 4         COVE DRIVE                   TURQUOISE           CCR  226.0
#
#   floorRange  noOfUnits  contractDate  typeOfSale    price   propertyType  \
# 0          -          1           220           3  5500000  Semi-detached
# 1          -          1           918           3  5000000  Semi-detached
# 2          -          1           618           3  4750000  Semi-detached
# 3          -          1           320           3  2630000        Terrace
# 4      01-05          1           920           3  3400000    Condominium
#
#    ...            x            y nettPrice  latitude   longitude  year  \
# 0  ...          NaN          NaN       NaN  1.282130  103.786879    20
# 1  ...          NaN          NaN       NaN  1.282130  103.786879    18
# 2  ...          NaN          NaN       NaN  1.282130  103.786879    18
# 3  ...          NaN          NaN       NaN  1.292047  103.768591    20
# 4  ...  28382.47067  25008.33592       NaN  1.244208  103.827487    20
#
#                                               school  \
# 0  ['JURONG SECONDARY SCHOOL', 'SCHOOL OF SCIENCE...
# 1  ['JURONG SECONDARY SCHOOL', 'SCHOOL OF SCIENCE...
# 2  ['JURONG SECONDARY SCHOOL', 'SCHOOL OF SCIENCE...
# 3  ['JURONG SECONDARY SCHOOL', 'SCHOOL OF SCIENCE...
# 4  ['QUEENSTOWN SECONDARY SCHOOL', "ST. MARGARET'...
#
#                                         hawkercentre  \
# 0  ['West Coast Drive Blk 503 (Ayer Rajah Food Ce...
# 1  ['West Coast Drive Blk 503 (Ayer Rajah Food Ce...
# 2  ['West Coast Drive Blk 503 (Ayer Rajah Food Ce...
# 3  ['West Coast Drive Blk 503 (Ayer Rajah Food Ce...
# 4  ['Telok Blangah Drive Blk 79 (Telok Blangah Fo...
#
#                                         supermarkets Bus Stops Nearby
# 0  ['U STARS SUPERMARKET PTE. LTD.', 'NTUC FAIRPR...                0
# 1  ['U STARS SUPERMARKET PTE. LTD.', 'NTUC FAIRPR...                0
# 2  ['U STARS SUPERMARKET PTE. LTD.', 'NTUC FAIRPR...                0
# 3  ['U STARS SUPERMARKET PTE. LTD.', 'NTUC FAIRPR...                2
# 4  ['NTUC FAIRPRICE CO-OPERATIVE LTD', 'THE QUALI...                0
#
# [5 rows x 23 columns]

# %% [markdown]
# ## 3. Combine Combined URA (ameneties_in_district) and average overall crime rates

# %% [markdown]
# Average Crime Rates Method
# - Using the average crime rates data, find the average overall crime rates for each district
# - Average overall crime rates refer to the sum of the average crime rates for all categories

# %%
# average_crimes_by_location_v3

# %%
# MAP AVERAGE_CRIMES_BY_LOCATION_V3 [POSTAL] COLUMN INTO A NEW COLUMN NAMED [DISTRICT]

# this dictionary shows the mapping from district > 1st 2 characters of postal
district_postal = { 
  '01': ['01', '02', '03', '04', '05', '06'],
  '02': ['07', '08'],
  '03': ['14', '15', '16'],
  '04': ['09', '10'],
  '05': ['11', '12', '13'], 
  '06': ['17'],
  '07': ['18', '19'],
  '08': ['20', '21'],
  '09': ['22', '23'],
  '10': ['24', '25', '26', '27'],
  '11': ['28', '29', '30'],
  '12': ['31', '32', '33'],
  '13': ['34', '35', '36', '37'],
  '14': ['38', '39', '40', '41'],
  '15': ['42', '43', '44', '45'],
  '16': ['46', '47', '48'],
  '17': ['49', '50', '81'],
  '18': ['51', '52'],
  '19': ['53', '54', '55', '82'],
  '20': ['56', '57'],
  '21': ['58', '59'],
  '22': ['60', '61', '62', '63', '64'],
  '23': ['65', '66', '67', '68'],
  '24': ['69', '70', '71'],
  '25': ['72', '73'],
  '26': ['77', '78'],
  '27': ['75', '76'],
  '28': ['79', '80']
}

# swap dictionary mapping direction
postal_district = {k: oldk for oldk, oldv in district_postal.items() for k in oldv}

# create new column to obtain the 1st 2 characters of [Postal]
average_crimes_by_location_v3['postal prefix'] = average_crimes_by_location_v3['Postal'].astype(str).str[0:2]

# map postal to district code
average_crimes_by_location_v3['district']= average_crimes_by_location_v3['postal prefix'].map(postal_district) 

# get overall crime rate in each district
average_crimes_by_location_v3 = average_crimes_by_location_v3.groupby(['district']).agg({'Number':'sum'}).reset_index()

# %%
# convert str to numpy
district_int = average_crimes_by_location_v3.district.astype(int)
district_int = pd.DataFrame(district_int)
average_crimes_by_location_v3['district'] = district_int

# %%
# combine ura_5y_trans and ameneties_per_district
ameneties_and_crime_in_district = ameneties_in_district.join(average_crimes_by_location_v3.set_index('district'), on='district')
print(ameneties_and_crime_in_district.shape)
ameneties_and_crime_in_district.head()
# Out:
# (73174, 24)
#               street                     project marketSegment   area  \
# 0       ZEHNDER ROAD  LANDED HOUSING DEVELOPMENT           RCR  524.3
# 1       ZEHNDER ROAD  LANDED HOUSING DEVELOPMENT           RCR  308.0
# 2       ZEHNDER ROAD  LANDED HOUSING DEVELOPMENT           RCR  314.0
# 3  NEO PEE TECK LANE  LANDED HOUSING DEVELOPMENT           RCR  159.3
# 4         COVE DRIVE                   TURQUOISE           CCR  226.0
#
#   floorRange  noOfUnits  contractDate  typeOfSale    price   propertyType  \
# 0          -          1           220           3  5500000  Semi-detached
# 1          -          1           918           3  5000000  Semi-detached
# 2          -          1           618           3  4750000  Semi-detached
# 3          -          1           320           3  2630000        Terrace
# 4      01-05          1           920           3  3400000    Condominium
#
#    ...            y nettPrice  latitude   longitude  year  \
# 0  ...          NaN       NaN  1.282130  103.786879    20
# 1  ...          NaN       NaN  1.282130  103.786879    18
# 2  ...          NaN       NaN  1.282130  103.786879    18
# 3  ...          NaN       NaN  1.292047  103.768591    20
# 4  ...  25008.33592       NaN  1.244208  103.827487    20
#
#                                               school  \
# 0  ['JURONG SECONDARY SCHOOL', 'SCHOOL OF SCIENCE...
# 1  ['JURONG SECONDARY SCHOOL', 'SCHOOL OF SCIENCE...
# 2  ['JURONG SECONDARY SCHOOL', 'SCHOOL OF SCIENCE...
# 3  ['JURONG SECONDARY SCHOOL', 'SCHOOL OF SCIENCE...
# 4  ['QUEENSTOWN SECONDARY SCHOOL', "ST. MARGARET'...
#
#                                         hawkercentre  \
# 0  ['West Coast Drive Blk 503 (Ayer Rajah Food Ce...
# 1  ['West Coast Drive Blk 503 (Ayer Rajah Food Ce...
# 2  ['West Coast Drive Blk 503 (Ayer Rajah Food Ce...
# 3  ['West Coast Drive Blk 503 (Ayer Rajah Food Ce...
# 4  ['Telok Blangah Drive Blk 79 (Telok Blangah Fo...
#
#                                         supermarkets  Bus Stops Nearby Number
# 0  ['U STARS SUPERMARKET PTE. LTD.', 'NTUC FAIRPR...                 0    NaN
# 1  ['U STARS SUPERMARKET PTE. LTD.', 'NTUC FAIRPR...                 0    NaN
# 2  ['U STARS SUPERMARKET PTE. LTD.', 'NTUC FAIRPR...                 0    NaN
# 3  ['U STARS SUPERMARKET PTE. LTD.', 'NTUC FAIRPR...                 2    NaN
# 4  ['NTUC FAIRPRICE CO-OPERATIVE LTD', 'THE QUALI...                 0    NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# Extrapolation Method (DOES NOT WORK)
# 1. Find out: In a year, for a postal code, what is the total number of offences in each category
# 2. Map Postal column into a new District column in overview_years_crimes_locations_v3
# 3. Do extrapolation and get data for 2018-2021
# 4. Merge the tables

# %%
# 1. FIND OUT IN A YEAR, FOR A POSTAL CODE, WHAT IS THE NUMBER OF OFFENCES IN EACH CATEGORY 
overview_years_crimes_locations_v3 = overview_years_crimes_locations_v3.groupby(['Year','Postal','Offence']).agg({'Number':'sum'}).reset_index()

# %%
# 2. MAP OVERVIEW_YEARS_CRIMES_LOCATIONS_V3 [POSTAL] COLUMN INTO A NEW COLUMN NAMED [DISTRICT]

# this dictionary shows the mapping from district > 1st 2 characters of postal
district_postal = { 
  '01': ['01', '02', '03', '04', '05', '06'],
  '02': ['07', '08'],
  '03': ['14', '15', '16'],
  '04': ['09', '10'],
  '05': ['11', '12', '13'], 
  '06': ['17'],
  '07': ['18', '19'],
  '08': ['20', '21'],
  '09': ['22', '23'],
  '10': ['24', '25', '26', '27'],
  '11': ['28', '29', '30'],
  '12': ['31', '32', '33'],
  '13': ['34', '35', '36', '37'],
  '14': ['38', '39', '40', '41'],
  '15': ['42', '43', '44', '45'],
  '16': ['46', '47', '48'],
  '17': ['49', '50', '81'],
  '18': ['51', '52'],
  '19': ['53', '54', '55', '82'],
  '20': ['56', '57'],
  '21': ['58', '59'],
  '22': ['60', '61', '62', '63', '64'],
  '23': ['65', '66', '67', '68'],
  '24': ['69', '70', '71'],
  '25': ['72', '73'],
  '26': ['77', '78'],
  '27': ['75', '76'],
  '28': ['79', '80']
}

# swap dictionary mapping direction
postal_district = {k: oldk for oldk, oldv in district_postal.items() for k in oldv}

# create new column to obtain the 1st 2 characters of [Postal]
overview_years_crimes_locations_v3['postal prefix'] = overview_years_crimes_locations_v3['Postal'].astype(str).str[0:2]

# map postal to district code
overview_years_crimes_locations_v3['district']= overview_years_crimes_locations_v3['postal prefix'].map(postal_district) 
overview_years_crimes_locations_v3
# Out:
#       Year  Postal                 Offence  Number postal prefix district
# 0     2012       -           Housebreaking     545             -      NaN
# 1     2012       -      Outrage Of Modesty    1398             -      NaN
# 2     2012       -                 Robbery     284             -      NaN
# 3     2012       -            Snatch Theft     286             -      NaN
# 4     2012       -  Theft Of Motor Vehicle     584             -      NaN
# ...    ...     ...                     ...     ...           ...      ...
# 1185  2018  828837           Housebreaking       5            82       19
# 1186  2018  828837      Outrage Of Modesty      23            82       19
# 1187  2018  828837                 Robbery       3            82       19
# 1188  2018  828837            Snatch Theft       1            82       19
# 1189  2018  828837  Theft Of Motor Vehicle       1            82       19
#
# [1190 rows x 6 columns]

# %%
# 3. EXTRAPOLATION TO GET DATA FOR 2018-2021

# %%
# find the distinct categories
overview_years_crimes_locations_v3.Offence.unique()
# Out:
# array(['Housebreaking', 'Outrage Of Modesty', 'Robbery', 'Snatch Theft',
#        'Theft Of Motor Vehicle'], dtype=object)

# %%
housebreaking = overview_years_crimes_locations_v3[overview_years_crimes_locations_v3['Offence']=='Housebreaking']
print(housebreaking.shape)

outrage_of_modesty = overview_years_crimes_locations_v3[overview_years_crimes_locations_v3['Offence']=='Outrage Of Modesty']
print(outrage_of_modesty.shape)

robbery = overview_years_crimes_locations_v3[overview_years_crimes_locations_v3['Offence']=='Robbery']
print(robbery.shape)

snatch_theft = overview_years_crimes_locations_v3[overview_years_crimes_locations_v3['Offence']=='Snatch Theft']
print(snatch_theft.shape)

theft_of_motor_vehicle = overview_years_crimes_locations_v3[overview_years_crimes_locations_v3['Offence']=='Theft Of Motor Vehicle']
print(theft_of_motor_vehicle.shape)

print('total: ',housebreaking.shape[0]+outrage_of_modesty.shape[0]+robbery.shape[0]+snatch_theft.shape[0]+theft_of_motor_vehicle.shape[0])
# Out:
# (238, 6)
# (238, 6)
# (238, 6)
# (238, 6)
# (238, 6)
# total:  1190

# %%
## for each district, find the trend of the number of cases over time

# %%
housebreaking = housebreaking.groupby(['Offence','district','Year']).agg({'Number':'sum'}).reset_index() 
housebreaking.district.unique() # find the district values present in housebreaking
# Out:
# array(['02', '03', '08', '09', '10', '12', '14', '15', '16', '18', '19',
#        '20', '22', '23', '25', '27'], dtype=object)

# %%
housebreaking_district2 = housebreaking.loc[housebreaking['district']=='02']
x = housebreaking_district2.Year
y = housebreaking_district2.Number
plt.plot(x,y)

# %%
housebreaking_district3 = housebreaking.loc[housebreaking['district']=='03']
x = housebreaking_district3.Year
y = housebreaking_district3.Number
plt.plot(x,y)

# %%
housebreaking_district8 = housebreaking.loc[housebreaking['district']=='08']
housebreaking_district9 = housebreaking.loc[housebreaking['district']=='09']
housebreaking_district10 = housebreaking.loc[housebreaking['district']=='10']

housebreaking_district12 = housebreaking.loc[housebreaking['district']=='12']

housebreaking_district14 = housebreaking.loc[housebreaking['district']=='14']
housebreaking_district15 = housebreaking.loc[housebreaking['district']=='15']
housebreaking_district16 = housebreaking.loc[housebreaking['district']=='16']

housebreaking_district18 = housebreaking.loc[housebreaking['district']=='18']
housebreaking_district19 = housebreaking.loc[housebreaking['district']=='19']
housebreaking_district20 = housebreaking.loc[housebreaking['district']=='20']

housebreaking_district22 = housebreaking.loc[housebreaking['district']=='22']
housebreaking_district23 = housebreaking.loc[housebreaking['district']=='23']

housebreaking_district25 = housebreaking.loc[housebreaking['district']=='25']

housebreaking_district27 = housebreaking.loc[housebreaking['district']=='27']

# %% [markdown]
# ## 4. Combine URA (combined data) and Resale Flat Prices

# %% [markdown]
# 1. Map Town column into a new District column in resale_flat_prices
# 2. Create Tenure column in resale_flat_prices
# 3. Convert to corresponding house type (?) - KIV

# %%
# 1. MAP RESALE_FLAT_PRICES [TOWN] COLUMN INTO A NEW COLUMN NAMED [DISTRICT]

# this dictionary shows the mapping from district > 1st 2 characters of postal
district_town = {
  '01': ['Raffles Place', 'Cecil', 'Marina', 'People’s Park'],
  '02': ['Anson', 'Tanjong Pagar'],
  '03': ['Queenstown', 'Tiong Bahru'],
  '04': ['Telok Blangah', 'Harbourfront'],
  '05': ['Pasir Panjang', 'Hong Leong Garden', 'Clementi New Town'], 
  '06': ['High Street', 'Beach Road'],
  '07': ['Middle Road', 'Golden Mile'],
  '08': ['Little India'],
  '09': ['Orchard', 'Cairnhill', 'River Valley'],
  '10': ['Ardmore', 'Bukit Timah', 'Holland Road', 'Tanglin'],
  '11': ['Watten Estate', 'Novena', 'Thomson'],
  '12': ['Balestier', 'Toa Payoh','Serangoon'],
  '13': ['Macpherson', 'Braddell'],
  '14': ['Geylang', 'Eunos'],
  '15': ['Katong', 'Joo Chiat', 'Amber Road'],
  '16': ['Bedok', 'Upper East Coast', 'Eastwood', 'Kew Drive'],
  '17': ['Loyang', 'Changi'],
  '18': ['Tampines', 'Pasir Ris'],
  '19': ['Serangoon Garden', 'Hougang', 'Punggol'],
  '20': ['Bishan', 'Ang Mo Kio'],
  '21': ['Upper Bukit Timah', 'Clementi Park', 'Ulu Pandan'],
  '22': ['Jurong'],
  '23': ['Hillview', 'Dairy Farm', 'Bukit Panjang', 'Choa Chu Kang'],
  '24': ['Lim Chu Kang', 'Tengah'],
  '25': ['Kranji', 'Woodgrove'],
  '26': ['Upper Thomson', 'Springleaf'],
  '27': ['Yishun', 'Sembawang'],
  '28': ['Seletar']
}
# convert all values to upper case
district_town = {key: [ele.upper() for ele in district_town[key] ] for key in district_town }

# swap dictionary mapping direction
town_district = {k: oldk for oldk, oldv in district_town.items() for k in oldv}

# map town to district code
resale_flat_prices['town'].str.upper()  # convert and ensure all town string in the data are in upper case 
resale_flat_prices['district'] = resale_flat_prices['town'].map(town_district)

# %%
# convert str to numpy
resale_district_int = resale_flat_prices.district.astype(int)
resale_district_int = pd.DataFrame(resale_district_int)
resale_flat_prices['district'] = resale_district_int

resale_flat_prices
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-dc287d84df5a> in <module>
#       1 # convert str to numpy
# ----> 2 resale_district_int = resale_flat_prices.district.astype(int)
#       3 resale_district_int = pd.DataFrame(resale_district_int)
#       4 resale_flat_prices['district'] = resale_district_int
#       5
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     557
#     558     def astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
# --> 559         return self._astype(dtype, copy=copy, errors=errors, values=values, **kwargs)
#     560
#     561     def _astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     641                     # _astype_nansafe works fine with 1-d only
#     642                     vals1d = values.ravel()
# --> 643                     values = astype_nansafe(vals1d, dtype, copy=True, **kwargs)
#     644
#     645                 # TODO(extension)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     705         # work around NumPy brokenness, #1987
#     706         if np.issubdtype(dtype.type, np.integer):
# --> 707             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     708
#     709         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: cannot convert float NaN to integer

# %%
# 2. CREATE TENURE COLUMN IN RESALE_FLAT_PRICES, USING THE REMAINING LEASE COLUMN

# %%
resale_flat_prices.columns # maybe this one can add the bus stops?
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date',
#        'remaining_lease', 'resale_price', 'street', 'latitude', 'longitude',
#        'district'],
#       dtype='object')

# %%
ameneties_in_district.columns
# Out:
# Index(['street', 'project', 'marketSegment', 'area', 'floorRange', 'noOfUnits',
#        'contractDate', 'typeOfSale', 'price', 'propertyType', 'district',
#        'typeOfArea', 'tenure', 'x', 'y', 'nettPrice', 'latitude', 'longitude',
#        'year', 'school', 'hawkercentre', 'supermarkets', 'Bus Stops Nearby'],
#       dtype='object')

# %%
# both got district, so can merge by that
test = pd.merge(resale_flat_prices,ameneties_in_district,on=['district'])

# %%
type(resale_flat_prices.district[1])
# Out:
# str
